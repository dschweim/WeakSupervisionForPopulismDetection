# %% [markdown]
# ### 1. Extract Segments for rows with no found matches

# %%
import pandas as pd

# %%
non = pd.read_csv("C:/Users/dschw/Documents/GitHub/Thesis/Output/df_none_match.csv")

# %%
non
# Out:
#      Unnamed: 0  index  Unnamed: 0.1                         ID  \
# 111         111   2581          3448  cd_tw_db_13284_00084z.txt
# 112         112   2592          3459  cd_tw_db_13313_00704z.txt
# 113         113   2596          3463  cd_tw_db_13341_00445z.txt
# 114         114   2612          3482  de_fb_db_15007_00023z.txt
# 115         115   2658          3529   de_fb_db_15039_00083.txt
# ..          ...    ...           ...                        ...
# 180         180   4630          6123  de_tw_db_15038_00274z.txt
# 181         181   4683          6183   de_tw_db_15058_01337.txt
# 182         182   4687          6187   de_tw_db_15058_01622.txt
# 183         183   4714          6216   de_tw_db_15061_00969.txt
# 184         184   4724          6227  de_tw_db_15080_00357z.txt
#
#                                                   text Coder           #TS  \
# 111  Text ID:\ncd_tw_db_13284_00084.txt\n\n\nTweet ...  kawa  1.455622e+09
# ...

# %%
# Remove rows from list where no manual retrievement possible and which have been fixed
drop_list = [0,5,9,14,15,16,18,30,31,32,33,34,35,36,40,42,46,50,53,57,59,60,61,
            62,63,64,65,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,83,84,85,86,
            87,88,89,90,91,92,93,100,103,104,105,106,111,112,113,115,116,
            117,118,119,120,121,122,123,124,125,126,127,129,131,132,134,135,136,
            137,138,139,140,141,142,146,147,148,149,151,152,153,154, 155,156,157,
            158,159,160,161,162,163,164,166,169,170,171,173,174,175,184]
replaced_list = none_match_replace.ID_non.values
non = non.loc[~non.index.isin(drop_list)]
non = non.loc[~non.index.isin(replaced_list)]

# %%
for index, row in non.iterrows():
    print(index)
    #print(row.text_prep)
    #print(row.text)
    print(row.doc_tokens)
    print(row.wording_tokens)
    print(row.Wording)
    print("----NEXT----")

# %%
data = [
    [1, 'SPOeOeVP-Regierung'],
    [2, 'Volksgruppen schuetzen Minderheiten foerdern'], 
    [3, 'BZOe-Forderungen'], 
    [4, 'Elite und Begabung'],
    [6, 'Die Politik greift'],
    [7, 'Wir fordern: - Eine wirksame'],
    [8, 'NGO fuer'],
    [10, 'SPOe-Vorsitzenden, Bundeskanzler WernerFaymann'],
    [11, 'Schwarz-Blau'],
    [12, 'Wir sind die Lobby der Jugendlichen'],
    [13, 'In Sachen ELGA'],
    [17, 'Das Schweigen der SPOe-Spitze'],
    [19, 'Bundeskanzler Michael Spindelegger'],
    [20, 'Die OeVP-Familie kaempft gemeinsam'],
    [21, 'SPOe gefaehrdet akut den Mittelstand und den Wohlstand'],
    [22, 'Als die fuer Verkehrsangelegenheiten'],
    [23, 'Die SPOe setzt'],
    [24, 'Faymann'],
    [25, 'OeVP legt'],
    [26, 'Gesundheitsminister Stoeger vorgeschlagen'],
    [27, 'SPOe steht'],
    [28, 'begruessen Amtsmissbrauchs-Anzeige'],
    [29, 'Doppler an'],
    [37, 'Herrn Kopf'],
    [38, 'Gesundheitsminister ist ja fuer seine'],
    [39, 'Regierungs-Entwurf'],
    [41, 'Ich frage mich nur'],
    [43, 'Weder die derzeitige Linie'],
    [44, 'Steuerzahler hat mehr als'],
    [45, 'Wir fordern: Runter mit den Steuern'],
    [47, 'Praesident Meidlinger'],
    [48, 'Die parlamentarische Anfrage'],
    [49, 'NEOS Spitzenkandidatin und LIF'],
    [51, 'Wir brauchen eine oesterreichweite'],
    [52, 'Mandatarin Martina Schenk noch einmal'],
    [54, 'SPOe-Bundeskanzler Faymann'],
    [55, 'Team Stronach fordert'],
    [56, 'Bundeskanzler Faymann'],
    [58, 'Grosse Koalition'],
    [66, 'die Rechte'],
    [82, 'Radikale Abtreibungsgegner'],
    [94, 'Obwohl die soziale Sicherheit noch Luecken'],
    [95, 'realitaetsfremde SP'],
    [96, 'Unsere Erfolge'],
    [97, 'Frau soll bei der naechsten'],
    [98, 'Umso wichtiger ist aber'],
    [99, 'befuerwortet eine aktive Aussenpolitik'],
    [101, 'gegen Steuerfusserhoehung'],
    [102, 'Investitionen wird weiterhin'],
    [107, 'In jedem andern Land'],
    [108, 'Stern'],
    [109, 'SVP-Familieninitiative'],
    [110, 'Pardon'],
    [114, 'Wir brauchen mehr'],
    [128, 'Lindner stellt mit Forderung'],
    [130, 'Damals'],
    [133, 'Terrorgruppe'],
    [143, 'Wir wollen die Regionalplanung'],
    [144, 'Wir wollen die Regionalplanung'],
    [145, 'Verfehlte'],
    [150, 'Zusammen mit der CDUCSU'],
    [165, 'SPD und Gruenen'],
    [167, 'unterstuetzt die Forderung des ADAC'],
    [168, 'Datenbestaende bei NSA'],
    [172, 'Strobl'],
    [176, 'Ruecktritt von Agrarminister'],
    [177, 'Unglaubwuerdigkeit der Politik'],
    [178, 'UN Sicherheitsrat'],
    [179, 'GroKo-Plan'],
    [180, 'Kaufpraemie fuer Elektroautos'],
    [181, 'Rechtspopulistischer'],
    [182, 'Ich seh auch'],
    [183, 'Lindner']  
    
    

]

# %%
#Generate Dataframe
none_match_replace = pd.DataFrame(data, columns = ['ID_non', 'Wording_fixed'])

# %%
none_match_replace
# Out:
#     ID_non                                 Wording_fixed
# 0        1                            SPOeOeVP-Regierung
# 1        2  Volksgruppen schuetzen Minderheiten foerdern
# 2        3                              BZOe-Forderungen
# 3        4                            Elite und Begabung
# 4        6                            Die Politik greift
# ..     ...                                           ...
# 68     179                                    GroKo-Plan
# 69     180                 Kaufpraemie fuer Elektroautos
# 70     181                          Rechtspopulistischer
# 71     182                                  Ich seh auch
# 72     183                                       Lindner
#
# [73 rows x 2 columns]

# %%
# Save to csv
none_match_replace.to_csv('C:/Users/dschw/Documents/GitHub/Thesis/Output/manual_replacement/none_match_replace_table.csv')

# %%
len(none_match_replace)
# Out:
# 73
