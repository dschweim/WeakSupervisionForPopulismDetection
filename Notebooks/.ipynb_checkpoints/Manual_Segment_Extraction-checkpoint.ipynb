# %% [markdown]
# ### 1. Extract Segments for rows with no found matches

# %%
import pandas as pd

# %%
non = pd.read_csv("C:/Users/dschw/Documents/GitHub/Thesis/Output/df_none_match.csv")
pd.set_option('display.max_rows', None)

# %%
len(non)
# Out:
# 183

# %%
# Remove rows from list where no manual retrievement possible and which have been fixed
drop_list = [6,13,16,17,18,21,26,39,40,41,42,43,46,47,51,52,55,56,57,60,64,70,71,72,73,74,75,76,78,
            79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,102,105,106,107,108,114,115,
            119,120,121,122,123,124,125,127,129,130,132,133,134,135,136,137,138,139,140,142,143,
             144,145,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,163,166,167,
             169,171,172,173,177,182]
             
             
replaced_list = none_match_replace.ID_non.values
non = non.loc[~non.index.isin(drop_list)]
non = non.loc[~non.index.isin(replaced_list)]

# %%
for index, row in non.iterrows():
    print(index)
    #print(row.text_prep)
    #print(row.text)
    #print(row.text)
    print(row.doc_tokens)
    print('--!!--Wording: ' + str(row.wording_tokens))
    print(row.Wording)
    print("----NEXT----")

# %%
data = [[0, 'SPÖÖVP-Regierung'],
[1, 'Verhältnisse'],
[2, 'Volksgruppen schützen'],
[3, 'BZÖ-Forderungen'],
[4, 'Elite und Begabung'],
[5, 'Beteiligungen des Staates'],
[7, 'Die Politik greift'],
[8, 'NGO für'],
[9, 'Bedarf an Kinderbetreuungsplätzen'],
[10, 'EU-Regierung'],
[11, 'von SPÖ-Vorsitzenden, Bundeskanzler WernerFaymann'],
[12, 'Schwarz-Blau'],
[14, 'In Sachen ELGA'],
[15, 'Einzigartig, dass eine Regierungspartei mit Schlamm'],
[19, 'Das Schweigen der SPÖ-Spitze'],
[20, 'Kennen die Grünen ihr eigenes Programm nicht?'],
[22, 'Bundeskanzler Michael Spindelegger'],
[23, 'Die ÖVP-Familie'],
[24, 'Die SPÖ gefährdet akut den Mittelstand'],
[25, 'Als die für Verkehrsangelegenheiten zuständige Ministerin'],
[27, 'Die SPÖ setzt'],
[28, 'Faymann'],
[29, 'ÖVP legt'],
[30, 'Gesundheitsminister Stöger'],
[31, 'SPÖ steht'],
[32, 'Herr Strache hat offenbar ein Problem mit der Wahrheit'],
[33, 'Ich schließe mich der Caritas an'],
[34, 'dass es Strache selbst war'],
[35, 'Dasselbe gelte naturgemäß'],
[36, 'Wir begrüßen das Vorhaben'],
[37, 'Amtsmissbrauchs-Anzeige'],
[38, 'Doppler'],
[44, 'Ursachen der Abwanderung und fehlenden Jugend'],
[45, 'gemäß einer Verordnung'],
[48, 'Herrn Kopf'],
[49, 'Gesundheitsminister'],
[50, 'Regierungs-Entwurf'],
[53, 'Der Frauenministerin fehlt der politische Weitblick'],
[54, 'Weder die derzeitige Linie'],
[58, 'Präsident Meidlinger'],
[59, 'Mein großer Mentor war mein Vater'],
[61, 'Wir brauchen eine österreichweite'],
[62, 'SPÖ Wählertäuschung vorwirft'],
[63, 'Team Stronach Mandatarin'],
[65, 'SPÖ-Bundeskanzler Faymann'],
[66, 'Team Stronach fordert'],
[67, 'Bundeskanzler Faymann'],
[68, 'roten Frauenministerinnen'],
[69, 'Damals hat die Große Koalition'],
[77, 'die Rechte'],
[98, 'realitätsfremde SP'],
[99, 'Die EDU Schweiz und ihr Profil'],
[100, 'Umso wichtiger'],
[101, 'befürwortet eine aktive Außenpolitik'],
[103, 'Investitionen wird weiterhin'],
[104, 'die Stärkung des Instrumentes'],
[109, 'In jedem andern Land'],
[110, 'Micheline Calmy-Rey'],
[111, 'Pädophile Grüne'],
[112, 'Unbehagen'],
[113, 'SVP-Familieninitiative'],
[116, 'CvanSinger'],
[117, 'Wir brauchen mehr'],
[118, 'Im April hat das Europäische Parlament'],
[126, 'Wirtschaftsfunktionäre und Lobbyisten'],
[128, 'Starker Antrag, starke Debatte'],
[131, 'Terrorgruppe'],
[141, 'tun ein übriges'],
[146, 'Zusammen mit der CDUCSU'],
[162, 'SPD und Grünen'],
[164, 'unterstützt die Forderung des ADAC'],
[165, 'Datenbestände'],
[168, 'humanitären Krise'],
[170, 'Strobl'],
[174, 'Wir Nationaldemokraten'],
[175, 'fordert den Rücktritt'],
[176, 'Unglaubwürdigkeit der Politik'],
[178, 'Kaufprämie'],
[179, 'Rechtspopulistischer CSU Pöbelslogan'],
[180, 'Auch CSU biedert'],
[181, 'Ich seh auch besser aus']]

# %%
x = 49
print(non.loc[x].Wording)
#print(non.iloc[x].doc_tokens)
#print(non.iloc[x].POPULIST)
#print('Wording: ' + str(non.iloc[x].Wording_temp))
#print(non.iloc[x].wording_sentence)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 49
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-a9900d89ec09> in <module>
#       1 x = 49
# ...

# %%
#Generate Dataframe
none_match_replace = pd.DataFrame(data, columns = ['ID_non', 'Wording_fixed'])

# %%
none_match_replace
# Out:
#     ID_non                                      Wording_fixed
# 0        0                                   SPÖÖVP-Regierung
# 1        1                                       Verhältnisse
# 2        2                              Volksgruppen schützen
# 3        3                                    BZÖ-Forderungen
# 4        4                                 Elite und Begabung
# 5        5                          Beteiligungen des Staates
# 6        7                                 Die Politik greift
# 7        8                                            NGO für
# 8        9                  Bedarf an Kinderbetreuungsplätzen
# 9       10                                       EU-Regierung
# 10      11  von SPÖ-Vorsitzenden, Bundeskanzler WernerFaymann
# 11      12                                       Schwarz-Blau
# 12      14                                     In Sachen ELGA
# 13      15  Einzigartig, dass eine Regierungspartei mit Sc...
# ...

# %%
# Save to csv
none_match_replace.to_csv('C:/Users/dschw/Documents/GitHub/Thesis/Output/manual_replacement/none_match_replace_table.csv')

# %%
len(none_match_replace)
# Out:
# 81
